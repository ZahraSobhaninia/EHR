# %%
from azureml.core import Workspace, Dataset, Datastore

# اتصال به Workspace
subscription_id = 'f8c5aac3-29fc-4387-858a-1f61722fb57a'
resource_group = 'forskerpl-n0ybkr-rg'
workspace_name = 'forskerpl-n0ybkr-mlw'

ws = Workspace(subscription_id=subscription_id,
               resource_group=resource_group,
               workspace_name=workspace_name)

# گرفتن datastore
datastore = Datastore.get(ws, "researcher_data")

# خواندن همه فایل‌های parquet در مسیر مشخص
dataset = Dataset.Tabular.from_parquet_files(
    path=[(datastore, 'Zahra/012026/Data/MEDS_MDP/data/train/*.parquet')]    #     Zahra/Data-07-2025/MDP/MEDS_811/data/train
)

# تبدیل به pandas DataFrame
df = dataset.to_pandas_dataframe()
df.head(15)
# Out:
# /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages/mlflow/__init__.py:41: UserWarning: Versions of mlflow (3.1.1) and mlflow-skinny (2.22.1) are different. This may lead to unexpected behavior. Please install the same version of both packages.
#   mlflow.mismatch._check_version_mismatch()
# Resolving access token for scope "https://storage.azure.com/.default" using identity of type "MANAGED".
# Getting data access token with Assigned Identity (client_id=clientid) and endpoint type based on configuration
# {'infer_column_types': 'False', 'activity': 'to_pandas_dataframe'}
# {'infer_column_types': 'False', 'activity': 'to_pandas_dataframe', 'activityApp': 'TabularDataset'}
#     subject_id                time       code  numeric_value
# 0           36 2001-05-30 00:00:00        DOB            NaN
# 1           36 2017-04-18 18:00:00  M/R06AD02            NaN
# 2           36 2017-04-19 08:00:00  M/R06AD02            NaN
# 3           36 2017-04-19 18:00:00  M/R06AD02            NaN
# 4           36 2017-04-20 08:00:00  M/R06AD02            NaN
# 5           36 2017-04-20 18:00:00  M/R06AD02            NaN
# 6           36 2017-04-21 08:00:00  M/R06AD02            NaN
# 7           36 2017-04-21 18:00:00  M/R06AD02            NaN
# 8           36 2017-04-22 08:00:00  M/R06AD02            NaN
# 9           36 2017-04-22 18:00:00  M/R06AD02            NaN
# 10          36 2017-04-23 08:00:00  M/R06AD02            NaN
# 11          36 2017-04-23 18:00:00  M/R06AD02            NaN
# 12          36 2017-04-24 08:00:00  M/R06AD02            NaN
# 13          36 2017-04-24 18:00:00  M/R06AD02            NaN
# 14          36 2017-04-25 08:00:00  M/R06AD02            NaN

# %%
len(df)
# Out:
# 363494992

# %%
import pandas as pd

# فرض بر این که فایل CSV رو داری
# df = pd.read_csv("your_file.csv")  # یا مستقیم اگر DataFrame آماده‌ست، نیازی نیست

# دسته‌بندی هر subject_id بر اساس وجود کدهای مختلف
m_patients = df[df['code'].str.startswith('M/', na=False)]['subject_id'].unique()
p_patients = df[df['code'].str.startswith('P/', na=False)]['subject_id'].unique()
d_patients = df[df['code'].str.startswith('D/', na=False)]['subject_id'].unique()
s_patients = df[df['code'].str.startswith('S/', na=False)]['subject_id'].unique()

# کل بیماران منحصربه‌فرد
all_patients = df['subject_id'].unique()

# نمایش آمار
print(f"Whole Patients: {len(all_patients)}")
print(f"The patients has M-medication Codes: {len(m_patients)}")
print(f"The patients has D-diagnosis Codes: {len(d_patients)}")
print(f"The patients has P-Procedure Codes: {len(p_patients)}")
print(f"The patients has S-SKS Codes: {len(s_patients)}")
# Out:
# Whole Patients: 1774422
# The patients has M-medication Codes: 1208927
# The patients has D-diagnosis Codes: 1773917
# The patients has P-Procedure Codes: 0
# The patients has S-SKS Codes: 0

# %%
subject_counts = df['subject_id'].value_counts()

# %%
subject_counts
# Out:
# 921542     77721
# 698589     61351
# 2016077    58264
# 954669     55553
# 1964088    52243
#            ...
# 1714923        2
# 484793         2
# 1550293        2
# 67442          2
# 513512         2
# Name: subject_id, Length: 1774422, dtype: int64

# %%
s_Num = df[df['code'].str.startswith('P/', na=False)]

# %%
s_Num
# Out:
# Empty DataFrame
# Columns: [subject_id, time, code, numeric_value]
# Index: []

# %%
import pandas as pd

# پیدا کردن سطرهایی که فقط codeهای نوع /P دارن
only_p = df[df['code'].str.startswith('P/', na=False)]

# بیماران با فقط /P کد
subject_ids_only_p = only_p['subject_id'].unique()

# حالا بیماران با codeهای غیر از /P
not_p = df[~df['code'].str.startswith('P/', na=False)]
subject_ids_with_non_p = set(not_p['subject_id'].unique())

# حذف بیمارانی که فقط /P دارن
only_p_ids_to_exclude = [sid for sid in subject_ids_only_p if sid not in subject_ids_with_non_p]

print("Number of patients with only Srugery code: ", only_p_ids_to_exclude)
# Out:
# Number of patients with only Srugery code:  []

# %%
df_filtered = df[~df['code'].str.startswith('P/', na=False)]

# %%
subject_counts_MDS = df_filtered['subject_id'].value_counts()

# %%
subject_counts_MDS
# Out:
# 921542     77721
# 698589     61351
# 2016077    58264
# 954669     55553
# 1964088    52243
#            ...
# 1714923        2
# 484793         2
# 1550293        2
# 67442          2
# 513512         2
# Name: subject_id, Length: 1774422, dtype: int64

# %%
subject_counts_df = subject_counts.reset_index()
subject_counts_df.columns = ['subject_id', 'original_count']

subject_counts_MDS_df = subject_counts_MDS.reset_index()
subject_counts_MDS_df.columns = ['subject_id', 'new_count']

# %%
import pandas as pd
comparison_df = pd.merge(subject_counts_df, subject_counts_MDS_df, on='subject_id', how='outer')

# %%
comparison_df['difference'] =  comparison_df['original_count'] - comparison_df['new_count']

# %%
comparison_df = comparison_df.sort_values(by='difference', ascending=False)

# %%
comparison_df
# Out:
#          subject_id  original_count  new_count  difference
# 0            921542           77721      77721           0
# 1182945       93782              24         24           0
# 1182956      422401              24         24           0
# 1182955      764854              24         24           0
# 1182954        9668              24         24           0
# ...             ...             ...        ...         ...
# 591469      1890824              89         89           0
# 591468      1977419              89         89           0
# 591467       431570              89         89           0
# 591466      1094467              89         89           0
# 1774421      513512               2          2           0
#
# [1774422 rows x 4 columns]

# %%
unchanged_count = (comparison_df['difference'] == 0).sum()
print("unchanged_count", unchanged_count)
# Out:
# unchanged_count 1774422

# %%
comparison_df['abs_diff'] = comparison_df['difference'].abs()
most_changed = comparison_df.sort_values(by='abs_diff', ascending=False)

# %%
print(most_changed.head(10))
# Out:
#     subject_id  original_count  new_count  difference  abs_diff
# 0       921542           77721      77721           0         0
# 14      948056           45606      45606           0         0
# 3       954669           55553      55553           0         0
# 4      1964088           52243      52243           0         0
# 5      1186037           51175      51175           0         0
# 6       821938           50295      50295           0         0
# 7      1291159           49845      49845           0         0
# 8       350138           49402      49402           0         0
# 9      1834955           49011      49011           0         0
# 10     1085114           47374      47374           0         0

# %%
changed_df = comparison_df[comparison_df['difference'] != 0]
min_new_count = changed_df['new_count'].min()
lowest_new_count_patients = changed_df[changed_df['new_count'] == min_new_count]

# %%
lowest_new_count_patients = lowest_new_count_patients.rename(
    columns={
        'original_count': 'MDPS codes',
        'new_count': 'MDP codes'
    }
)

# %%
lowest_new_count_patients
# Out:
# Empty DataFrame
# Columns: [subject_id, MDPS codes, MDP codes, difference, abs_diff]
# Index: []

# %% [markdown]
# .str.upper() شرط را case-insensitive می‌کند
#
# بل از فیلتر، ستون را به pd.StringDtype() تبدیل می‌کند؛ این کار رفتار .str را پایدار و قابل پیش‌بینی می‌کند (<NA> به‌جای NaN)

# %%
# کل بیماران منحصربه‌فرد
all_patients = df_filtered['subject_id'].unique()
len(all_patients)
# نمایش آمار
# Out:
# 1774422

# %%
len(df_filtered)
# Out:
# 363494992

# %%
import pandas as pd
import numpy as np

# امن‌تر: اگر code نال یا غیررشته‌ای بود اذیت نکنه
df['code'] = df['code'].astype('string')
df_filtered = df[~df['code'].str.upper().str.startswith('P/', na=False)].copy()
print("kept rows MDP:", len(df_filtered), " / total:", len(df))
# Out:
# kept rows MDP: 363494992  / total: 363494992

# %%
import pandas as pd
import numpy as np

# اطمینان از نوع‌ها (برای خروجی تمیز و بدون خطا)
df_filtered = df_filtered.copy()
df_filtered['subject_id']    = pd.to_numeric(df_filtered['subject_id'], errors='coerce').astype('Int64')
df_filtered['numeric_value'] = pd.to_numeric(df_filtered['numeric_value'], errors='coerce').astype('float32')
df_filtered['time']          = pd.to_datetime(df_filtered['time'], errors='coerce', utc=False)

# ردیف‌های بدون subject_id را حذف کنیم (نمی‌توان شارد کرد)
df_filtered = df_filtered.dropna(subset=['subject_id']).copy()
df_filtered['subject_id'] = df_filtered['subject_id'].astype('int64')

# ۳۶ شارد: هر بیمار فقط در یک فایل (mod 36)
N_SHARDS = 45
df_filtered['__shard__'] = (df_filtered['subject_id'] % N_SHARDS).astype('int16')

print("rows to write:", len(df_filtered))
# Out:
# rows to write: 363494992

# %%
import numpy as np
import os

N_SHARDS = 36   #45 for Whole # 36 when we have split
OUT_DIR = "./_TrainMDP_withoutP_sharded"
os.makedirs(OUT_DIR, exist_ok=True)

cols_out = ['subject_id', 'time', 'code', 'numeric_value']

# فرض: subject_id قبلاً int64 شده و NaNها حذف شده‌اند (طبق سلول قبلی‌ات)
sid_mod = (df_filtered['subject_id'].to_numpy(dtype=np.int64, copy=False) % N_SHARDS)

written = 0
for k in range(N_SHARDS):
    mask = (sid_mod == k)                 # بدون ستون اضافی، فقط یک آرایهٔ NumPy
    part = df_filtered.loc[mask, cols_out].sort_values(['subject_id','time'])
    # اگر می‌خوای حتماً ۳۶ فایل 0..35 داشته باشی حتی اگه خالی باشن:
    # if part.empty:
    #     part = part.iloc[0:0]  # فایل صفر-سطر با همان ستون‌ها
    part.to_parquet(os.path.join(OUT_DIR, f"{k}.parquet"),
                    engine="pyarrow", compression="snappy", index=False)
    written += 1

print(f"Done. wrote {written} parquet files into {OUT_DIR}")
# Out:
# Done. wrote 36 parquet files into ./_TrainMDP_withoutP_sharded

# %%
import pyarrow.parquet as pq

OUT_DIR = "./_TrainMDP_withoutP_sharded"

def parquet_num_rows(path):
    pf = pq.ParquetFile(path)
    md = pf.metadata
    return sum(md.row_group(i).num_rows for i in range(md.num_row_groups))

total = 0
for f in sorted(p for p in os.listdir(OUT_DIR) if p.endswith('.parquet')):
    n = parquet_num_rows(os.path.join(OUT_DIR, f))
    total += n
    print(f, "rows:", n)
print("TOTAL rows:", total)
# Out:
# 0.parquet rows: 10026591
# 1.parquet rows: 10134318
# 10.parquet rows: 9777004
# 11.parquet rows: 10076212
# 12.parquet rows: 9958665
# 13.parquet rows: 10162382
# 14.parquet rows: 10107719
# 15.parquet rows: 10062800
# 16.parquet rows: 9994590
# 17.parquet rows: 9911632
# 18.parquet rows: 10171298
# 19.parquet rows: 10379819
# 2.parquet rows: 10222383
# 20.parquet rows: 10083224
# 21.parquet rows: 10192484
# 22.parquet rows: 10340625
# 23.parquet rows: 10169205
# 24.parquet rows: 9965616
# 25.parquet rows: 10116192
# 26.parquet rows: 10187812
# 27.parquet rows: 10022729
# 28.parquet rows: 10315881
# 29.parquet rows: 9884987
# 3.parquet rows: 9974118
# 30.parquet rows: 9953999
# 31.parquet rows: 10121189
# 32.parquet rows: 10238756
# 33.parquet rows: 10105360
# 34.parquet rows: 9842052
# 35.parquet rows: 10094384
# 4.parquet rows: 9877481
# 5.parquet rows: 10392989
# 6.parquet rows: 10199434
# 7.parquet rows: 9908729
# 8.parquet rows: 10296476
# 9.parquet rows: 10225857
# TOTAL rows: 363494992

# %%
from azureml.data.datapath import DataPath
from azureml.data.dataset_factory import FileDatasetFactory
import os

OUT_DIR = "./_TrainMDP_withoutP_sharded"
DST_PREFIX = "Zahra/012026/Data/MEDS_MD/data/train"  #held_out"  # بدون اسلشِ اول
''

# اطمینان: پوشه خروجی وجود دارد و فایل parquet داخلش هست
print("Local files to upload:", len([f for f in os.listdir(OUT_DIR) if f.endswith(".parquet")]))

# مقصد روی Datastore
target = DataPath(datastore, DST_PREFIX)

# آپلود همه محتویات OUT_DIR به DST_PREFIX
_ = FileDatasetFactory.upload_directory(
    src_dir=OUT_DIR,
    target=target,
    overwrite=True,
    show_progress=True,
)
print(f"Uploaded to datastore path: {DST_PREFIX}")
# Out:
# Local files to upload: 36
# Validating arguments.
# Arguments validated.
# 'overwrite' is set to True. Any file already present in the target will be overwritten.
# Uploading files from '/mnt/batch/tasks/shared/LS_root/mounts/clusters/zahra/code/Users/zahra.sobhaninia/Corebehrt_CV/CreateIdenticalData/_TrainMDP_withoutP_sharded' to 'Zahra/012026/Data/MEDS_MD/data/train'
# Copying 36 files with concurrency set to 6
# Copied /mnt/batch/tasks/shared/LS_root/mounts/clusters/zahra/code/Users/zahra.sobhaninia/Corebehrt_CV/CreateIdenticalData/_TrainMDP_withoutP_sharded/13.parquet, file 1 out of 36. Destination path: https://forskerpln0ybkrdls01.dfs.core.windows.net/researcher-data/Zahra/012026/Data/MEDS_MD/data/train/13.parquet
# Copied /mnt/batch/tasks/shared/LS_root/mounts/clusters/zahra/code/Users/zahra.sobhaninia/Corebehrt_CV/CreateIdenticalData/_TrainMDP_withoutP_sharded/0.parquet, file 2 out of 36. Destination path: https://forskerpln0ybkrdls01.dfs.core.windows.net/researcher-data/Zahra/012026/Data/MEDS_MD/data/train/0.parquet
# Copied /mnt/batch/tasks/shared/LS_root/mounts/clusters/zahra/code/Users/zahra.sobhaninia/Corebehrt_CV/CreateIdenticalData/_TrainMDP_withoutP_sharded/10.parquet, file 3 out of 36. Destination path: https://forskerpln0ybkrdls01.dfs.core.windows.net/researcher-data/Zahra/012026/Data/MEDS_MD/data/train/10.parquet
# Copied /mnt/batch/tasks/shared/LS_root/mounts/clusters/zahra/code/Users/zahra.sobhaninia/Corebehrt_CV/CreateIdenticalData/_TrainMDP_withoutP_sharded/11.parquet, file 4 out of 36. Destination path: https://forskerpln0ybkrdls01.dfs.core.windows.net/researcher-data/Zahra/012026/Data/MEDS_MD/data/train/11.parquet
# Copied /mnt/batch/tasks/shared/LS_root/mounts/clusters/zahra/code/Users/zahra.sobhaninia/Corebehrt_CV/CreateIdenticalData/_TrainMDP_withoutP_sharded/12.parquet, file 5 out of 36. Destination path: https://forskerpln0ybkrdls01.dfs.core.windows.net/researcher-data/Zahra/012026/Data/MEDS_MD/data/train/12.parquet
# Copied /mnt/batch/tasks/shared/LS_root/mounts/clusters/zahra/code/Users/zahra.sobhaninia/Corebehrt_CV/CreateIdenticalData/_TrainMDP_withoutP_sharded/1.parquet, file 6 out of 36. Destination path: https://forskerpln0ybkrdls01.dfs.core.windows.net/researcher-data/Zahra/012026/Data/MEDS_MD/data/train/1.parquet
# Copied /mnt/batch/tasks/shared/LS_root/mounts/clusters/zahra/code/Users/zahra.sobhaninia/Corebehrt_CV/CreateIdenticalData/_TrainMDP_withoutP_sharded/19.parquet, file 7 out of 36. Destination path: https://forskerpln0ybkrdls01.dfs.core.windows.net/researcher-data/Zahra/012026/Data/MEDS_MD/data/train/19.parquet
# Copied /mnt/batch/tasks/shared/LS_root/mounts/clusters/zahra/code/Users/zahra.sobhaninia/Corebehrt_CV/CreateIdenticalData/_TrainMDP_withoutP_sharded/14.parquet, file 8 out of 36. Destination path: https://forskerpln0ybkrdls01.dfs.core.windows.net/researcher-data/Zahra/012026/Data/MEDS_MD/data/train/14.parquet
# Copied /mnt/batch/tasks/shared/LS_root/mounts/clusters/zahra/code/Users/zahra.sobhaninia/Corebehrt_CV/CreateIdenticalData/_TrainMDP_withoutP_sharded/16.parquet, file 9 out of 36. Destination path: https://forskerpln0ybkrdls01.dfs.core.windows.net/researcher-data/Zahra/012026/Data/MEDS_MD/data/train/16.parquet
# Copied /mnt/batch/tasks/shared/LS_root/mounts/clusters/zahra/code/Users/zahra.sobhaninia/Corebehrt_CV/CreateIdenticalData/_TrainMDP_withoutP_sharded/18.parquet, file 10 out of 36. Destination path: https://forskerpln0ybkrdls01.dfs.core.windows.net/researcher-data/Zahra/012026/Data/MEDS_MD/data/train/18.parquet
# Copied /mnt/batch/tasks/shared/LS_root/mounts/clusters/zahra/code/Users/zahra.sobhaninia/Corebehrt_CV/CreateIdenticalData/_TrainMDP_withoutP_sharded/17.parquet, file 11 out of 36. Destination path: https://forskerpln0ybkrdls01.dfs.core.windows.net/researcher-data/Zahra/012026/Data/MEDS_MD/data/train/17.parquet
# Copied /mnt/batch/tasks/shared/LS_root/mounts/clusters/zahra/code/Users/zahra.sobhaninia/Corebehrt_CV/CreateIdenticalData/_TrainMDP_withoutP_sharded/24.parquet, file 12 out of 36. Destination path: https://forskerpln0ybkrdls01.dfs.core.windows.net/researcher-data/Zahra/012026/Data/MEDS_MD/data/train/24.parquet
# Copied /mnt/batch/tasks/shared/LS_root/mounts/clusters/zahra/code/Users/zahra.sobhaninia/Corebehrt_CV/CreateIdenticalData/_TrainMDP_withoutP_sharded/15.parquet, file 13 out of 36. Destination path: https://forskerpln0ybkrdls01.dfs.core.windows.net/researcher-data/Zahra/012026/Data/MEDS_MD/data/train/15.parquet
# Copied /mnt/batch/tasks/shared/LS_root/mounts/clusters/zahra/code/Users/zahra.sobhaninia/Corebehrt_CV/CreateIdenticalData/_TrainMDP_withoutP_sharded/21.parquet, file 14 out of 36. Destination path: https://forskerpln0ybkrdls01.dfs.core.windows.net/researcher-data/Zahra/012026/Data/MEDS_MD/data/train/21.parquet
# Copied /mnt/batch/tasks/shared/LS_root/mounts/clusters/zahra/code/Users/zahra.sobhaninia/Corebehrt_CV/CreateIdenticalData/_TrainMDP_withoutP_sharded/2.parquet, file 15 out of 36. Destination path: https://forskerpln0ybkrdls01.dfs.core.windows.net/researcher-data/Zahra/012026/Data/MEDS_MD/data/train/2.parquet
# Copied /mnt/batch/tasks/shared/LS_root/mounts/clusters/zahra/code/Users/zahra.sobhaninia/Corebehrt_CV/CreateIdenticalData/_TrainMDP_withoutP_sharded/23.parquet, file 16 out of 36. Destination path: https://forskerpln0ybkrdls01.dfs.core.windows.net/researcher-data/Zahra/012026/Data/MEDS_MD/data/train/23.parquet
# Copied /mnt/batch/tasks/shared/LS_root/mounts/clusters/zahra/code/Users/zahra.sobhaninia/Corebehrt_CV/CreateIdenticalData/_TrainMDP_withoutP_sharded/22.parquet, file 17 out of 36. Destination path: https://forskerpln0ybkrdls01.dfs.core.windows.net/researcher-data/Zahra/012026/Data/MEDS_MD/data/train/22.parquet
# Copied /mnt/batch/tasks/shared/LS_root/mounts/clusters/zahra/code/Users/zahra.sobhaninia/Corebehrt_CV/CreateIdenticalData/_TrainMDP_withoutP_sharded/20.parquet, file 18 out of 36. Destination path: https://forskerpln0ybkrdls01.dfs.core.windows.net/researcher-data/Zahra/012026/Data/MEDS_MD/data/train/20.parquet
# Copied /mnt/batch/tasks/shared/LS_root/mounts/clusters/zahra/code/Users/zahra.sobhaninia/Corebehrt_CV/CreateIdenticalData/_TrainMDP_withoutP_sharded/27.parquet, file 19 out of 36. Destination path: https://forskerpln0ybkrdls01.dfs.core.windows.net/researcher-data/Zahra/012026/Data/MEDS_MD/data/train/27.parquet
# Copied /mnt/batch/tasks/shared/LS_root/mounts/clusters/zahra/code/Users/zahra.sobhaninia/Corebehrt_CV/CreateIdenticalData/_TrainMDP_withoutP_sharded/3.parquet, file 20 out of 36. Destination path: https://forskerpln0ybkrdls01.dfs.core.windows.net/researcher-data/Zahra/012026/Data/MEDS_MD/data/train/3.parquet
# Copied /mnt/batch/tasks/shared/LS_root/mounts/clusters/zahra/code/Users/zahra.sobhaninia/Corebehrt_CV/CreateIdenticalData/_TrainMDP_withoutP_sharded/28.parquet, file 21 out of 36. Destination path: https://forskerpln0ybkrdls01.dfs.core.windows.net/researcher-data/Zahra/012026/Data/MEDS_MD/data/train/28.parquet
# Copied /mnt/batch/tasks/shared/LS_root/mounts/clusters/zahra/code/Users/zahra.sobhaninia/Corebehrt_CV/CreateIdenticalData/_TrainMDP_withoutP_sharded/29.parquet, file 22 out of 36. Destination path: https://forskerpln0ybkrdls01.dfs.core.windows.net/researcher-data/Zahra/012026/Data/MEDS_MD/data/train/29.parquet
# Copied /mnt/batch/tasks/shared/LS_root/mounts/clusters/zahra/code/Users/zahra.sobhaninia/Corebehrt_CV/CreateIdenticalData/_TrainMDP_withoutP_sharded/25.parquet, file 23 out of 36. Destination path: https://forskerpln0ybkrdls01.dfs.core.windows.net/researcher-data/Zahra/012026/Data/MEDS_MD/data/train/25.parquet
# Copied /mnt/batch/tasks/shared/LS_root/mounts/clusters/zahra/code/Users/zahra.sobhaninia/Corebehrt_CV/CreateIdenticalData/_TrainMDP_withoutP_sharded/32.parquet, file 24 out of 36. Destination path: https://forskerpln0ybkrdls01.dfs.core.windows.net/researcher-data/Zahra/012026/Data/MEDS_MD/data/train/32.parquet
# Copied /mnt/batch/tasks/shared/LS_root/mounts/clusters/zahra/code/Users/zahra.sobhaninia/Corebehrt_CV/CreateIdenticalData/_TrainMDP_withoutP_sharded/35.parquet, file 25 out of 36. Destination path: https://forskerpln0ybkrdls01.dfs.core.windows.net/researcher-data/Zahra/012026/Data/MEDS_MD/data/train/35.parquet
# Copied /mnt/batch/tasks/shared/LS_root/mounts/clusters/zahra/code/Users/zahra.sobhaninia/Corebehrt_CV/CreateIdenticalData/_TrainMDP_withoutP_sharded/26.parquet, file 26 out of 36. Destination path: https://forskerpln0ybkrdls01.dfs.core.windows.net/researcher-data/Zahra/012026/Data/MEDS_MD/data/train/26.parquet
# Copied /mnt/batch/tasks/shared/LS_root/mounts/clusters/zahra/code/Users/zahra.sobhaninia/Corebehrt_CV/CreateIdenticalData/_TrainMDP_withoutP_sharded/33.parquet, file 27 out of 36. Destination path: https://forskerpln0ybkrdls01.dfs.core.windows.net/researcher-data/Zahra/012026/Data/MEDS_MD/data/train/33.parquet
# Copied /mnt/batch/tasks/shared/LS_root/mounts/clusters/zahra/code/Users/zahra.sobhaninia/Corebehrt_CV/CreateIdenticalData/_TrainMDP_withoutP_sharded/34.parquet, file 28 out of 36. Destination path: https://forskerpln0ybkrdls01.dfs.core.windows.net/researcher-data/Zahra/012026/Data/MEDS_MD/data/train/34.parquet
# Copied /mnt/batch/tasks/shared/LS_root/mounts/clusters/zahra/code/Users/zahra.sobhaninia/Corebehrt_CV/CreateIdenticalData/_TrainMDP_withoutP_sharded/30.parquet, file 29 out of 36. Destination path: https://forskerpln0ybkrdls01.dfs.core.windows.net/researcher-data/Zahra/012026/Data/MEDS_MD/data/train/30.parquet
# Copied /mnt/batch/tasks/shared/LS_root/mounts/clusters/zahra/code/Users/zahra.sobhaninia/Corebehrt_CV/CreateIdenticalData/_TrainMDP_withoutP_sharded/6.parquet, file 30 out of 36. Destination path: https://forskerpln0ybkrdls01.dfs.core.windows.net/researcher-data/Zahra/012026/Data/MEDS_MD/data/train/6.parquet
# Copied /mnt/batch/tasks/shared/LS_root/mounts/clusters/zahra/code/Users/zahra.sobhaninia/Corebehrt_CV/CreateIdenticalData/_TrainMDP_withoutP_sharded/9.parquet, file 31 out of 36. Destination path: https://forskerpln0ybkrdls01.dfs.core.windows.net/researcher-data/Zahra/012026/Data/MEDS_MD/data/train/9.parquet
# Copied /mnt/batch/tasks/shared/LS_root/mounts/clusters/zahra/code/Users/zahra.sobhaninia/Corebehrt_CV/CreateIdenticalData/_TrainMDP_withoutP_sharded/31.parquet, file 32 out of 36. Destination path: https://forskerpln0ybkrdls01.dfs.core.windows.net/researcher-data/Zahra/012026/Data/MEDS_MD/data/train/31.parquet
# Copied /mnt/batch/tasks/shared/LS_root/mounts/clusters/zahra/code/Users/zahra.sobhaninia/Corebehrt_CV/CreateIdenticalData/_TrainMDP_withoutP_sharded/7.parquet, file 33 out of 36. Destination path: https://forskerpln0ybkrdls01.dfs.core.windows.net/researcher-data/Zahra/012026/Data/MEDS_MD/data/train/7.parquet
# Copied /mnt/batch/tasks/shared/LS_root/mounts/clusters/zahra/code/Users/zahra.sobhaninia/Corebehrt_CV/CreateIdenticalData/_TrainMDP_withoutP_sharded/8.parquet, file 34 out of 36. Destination path: https://forskerpln0ybkrdls01.dfs.core.windows.net/researcher-data/Zahra/012026/Data/MEDS_MD/data/train/8.parquet
# Copied /mnt/batch/tasks/shared/LS_root/mounts/clusters/zahra/code/Users/zahra.sobhaninia/Corebehrt_CV/CreateIdenticalData/_TrainMDP_withoutP_sharded/4.parquet, file 35 out of 36. Destination path: https://forskerpln0ybkrdls01.dfs.core.windows.net/researcher-data/Zahra/012026/Data/MEDS_MD/data/train/4.parquet
# Copied /mnt/batch/tasks/shared/LS_root/mounts/clusters/zahra/code/Users/zahra.sobhaninia/Corebehrt_CV/CreateIdenticalData/_TrainMDP_withoutP_sharded/5.parquet, file 36 out of 36. Destination path: https://forskerpln0ybkrdls01.dfs.core.windows.net/researcher-data/Zahra/012026/Data/MEDS_MD/data/train/5.parquet
# Files copied=36, skipped=0, failed=0
# Creating new dataset
# Uploaded to datastore path: Zahra/012026/Data/MEDS_MD/data/train

# %%
paths = Dataset.File.from_files(path=[(datastore, f"{DST_PREFIX}/*.parquet")]).to_path()
print("Found in datastore:", len(paths))
print(paths[:20])
# Out:
# {'infer_column_types': 'False', 'activity': 'to_path'}
# {'infer_column_types': 'False', 'activity': 'to_path', 'activityApp': 'FileDataset'}
# Found in datastore: 36
# ['/0.parquet', '/1.parquet', '/10.parquet', '/11.parquet', '/12.parquet', '/13.parquet', '/14.parquet', '/15.parquet', '/16.parquet', '/17.parquet', '/18.parquet', '/19.parquet', '/2.parquet', '/20.parquet', '/21.parquet', '/22.parquet', '/23.parquet', '/24.parquet', '/25.parquet', '/26.parquet']
